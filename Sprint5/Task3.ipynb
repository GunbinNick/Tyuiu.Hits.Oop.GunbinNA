// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 4

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Product в C#, который будет представлять информацию о
// продуктах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) исользуйтие в проекте коллекции, делегаты, события.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;
using System.Collections.ObjectModel;

public abstract class Product
{
    public string Name { get; set; }
    public string Manufacturer { get; set; }
    public int Price { get; set; }
    public double Weight { get; set; }
    public DateTime ReleaseDate { get; set; }

    public Product(string name, string manufacturer, int price, double weight, DateTime releaseDate)
    {
        Name = name;
        Manufacturer = manufacturer;
        Price = price;
        Weight = weight;
        ReleaseDate = releaseDate;
    }

    public virtual string GetInfo()
    {
        return $"Название - {Name}; Производитель - {Manufacturer}; Цена - {Price} руб.; Вес - {Weight} кг.; Дата выпуска - {ReleaseDate:dd.MM.yyyy}";
    }

    public virtual void Discount()
    {
        Console.WriteLine($"Применена скидка на '{Name}' от производителя {Manufacturer}. Итоговая стоимость - {Price * 0.75} руб.");
    }

    public virtual void Display()
    {
        Console.WriteLine($"Отображение товара {Name} от {Manufacturer} на экране.");
    }

    public virtual void CalculateShippingCost()
    {
        double shippingCost = Weight * 10;
        Console.WriteLine($"Стоимость доставки для {Name} - {shippingCost} руб.\n");
    }
}

public interface IClothes
{
    int Size { get; set; }
    void CheckFit(int userSize);
}

public class Clothing : Product, IClothes
{
    public int Size { get; set; }
    public string Material { get; set; }
    public string Color { get; set; }

    public Clothing(string name, string manufacturer, int price, double weight, DateTime releaseDate, int size, string material, string color) 
        : base(name, manufacturer, price, weight, releaseDate)
    {
        Size = size;
        Material = material;
        Color = color;
    }

    public override string GetInfo()
    {
        return $"{base.GetInfo()}; Размер - {Size}; Материал - {Material}; Цвет - {Color}";
    }

    public override void Display()
    {
        Console.WriteLine($"Отображение товара {Name} от {Manufacturer} размера {Size} на экране.");
    }

    void IClothes.CheckFit(int userSize)
    {
        if (userSize == Size)
        {
            Console.WriteLine($"Одежда {Name} подходит по размеру.\n");
        }
        else
        {
            Console.WriteLine($"Одежда {Name} не подходит по размеру.\n");
        }
    }

    public void ChangeColor(string newColor)
    {
        Color = newColor;
        Console.WriteLine($"Цвет одежды {Name} изменен на {Color}.\n");
    }
}

public class Books : Product
{
    public string Author { get; set; }
    public int Pages { get; set; }
    public string ISBN { get; set; }

    public Books(string name, string manufacturer, int price, double weight, DateTime releaseDate, string author, int pages, string isbn) 
        : base(name, manufacturer, price, weight, releaseDate)
    {
        Author = author;
        Pages = pages;
        ISBN = isbn;
    }

    public override string GetInfo()
    {
        return $"{base.GetInfo()}; Автор - {Author}; Страниц - {Pages}; ISBN - {ISBN}";
    }

    public void CalculateReadingTime(int readingSpeed)
    {
        double hours = Pages / readingSpeed;
        Console.WriteLine($"Время чтения книги '{Name}' - {hours} часов.\n");
    }

    public void CheckAvailability()
    {
        Console.WriteLine($"Книга '{Name}' доступна в наличии.\n");
    }
}

public class Fiction : Books
{
    public string Genre { get; set; }

    public Fiction(string name, string manufacturer, int price, double weight, DateTime releaseDate, string author, int pages, string isbn, string genre) 
        : base(name, manufacturer, price, weight, releaseDate, author, pages, isbn)
    {
        Genre = genre;
    }

    public override string GetInfo()
    {
        return $"{base.GetInfo()}; Жанр - {Genre} ";
    }

    public void RecommendSimilarBooks()
    {
        Console.WriteLine($"Рекомендуем книги в жанре {Genre}.\n");
    }
}

public class Electronics : Product
{
    public int WarrantyPeriod { get; set; }
    public int PowerConsumption { get; set; }
    public string Model { get; set; }

    public Electronics(string name, string manufacturer, int price, double weight, DateTime releaseDate, int warrantyPeriod, int powerConsumption, string model) 
        : base(name, manufacturer, price, weight, releaseDate)
    {
        WarrantyPeriod = warrantyPeriod;
        PowerConsumption = powerConsumption;
        Model = model;
    }

    public override string GetInfo()
    {
        return $"{base.GetInfo()}; Гарантия - {WarrantyPeriod} года; Потребление энергии - {PowerConsumption} Вт; Модель - {Model}";
    }

    public override void Discount()
    {
        Console.WriteLine($"Применена скидка на '{Name}' от производителя {Manufacturer} с гарантией {WarrantyPeriod} года. Итоговая стоимость - {Price * 0.75} руб., Гарантия переопределена - {WarrantyPeriod / 2} года");
    }

    public void CalculateEnergyCost(int hoursPerDay, int daysPerYear, double pricePerKWh)
    {
        double energyConsumption = PowerConsumption * hoursPerDay * daysPerYear / 1000.0;
        double totalCost = energyConsumption * pricePerKWh;
        Console.WriteLine($"Годовая стоимость энергии для {Name} - {totalCost} руб.\n");
    }

    public void CheckCompatibility(string otherModel)
    {
        Console.WriteLine($"Проверка совместимости {Name} с моделью {otherModel}.\n");
    }
}

public class ProductList<T> where T : Product
{
    private ObservableCollection<T> products = new ObservableCollection<T>();

    public delegate void ProductAddedHandler(T product);
    public event ProductAddedHandler ProductAdded;

    public void AddProduct(T product)
    {
        products.Add(product);
        ProductAdded?.Invoke(product);
    }

    public void DisplayAll()
    {
        foreach (var product in products)
        {
            product.Display();
        }
    }

    public List<T> FilterByPrice(int maxPrice)
    {
        List<T> filteredProducts = new List<T>();
        foreach (var product in products)
        {
            if (product.Price <= maxPrice)
            {
                filteredProducts.Add(product);
            }
        }
        return filteredProducts;
    }
}

ProductList<Product> productList = new ProductList<Product>();
productList.ProductAdded += OnProductAdded;

// Создание объектов и добавление их в список
Fiction diction = new Fiction("1984", "Издательство АСТ", 239, 0.5, new DateTime(1949, 6, 8), "Дж. Оруэлл", 328, "978-5-17-103394-7", "Художественная литература");
productList.AddProduct(diction);

Clothing clother = new Clothing("Худи", "OffWhite", 19299, 0.8, new DateTime(2023, 1, 1), 56, "Хлопок", "Черный");
productList.AddProduct(clother);

Electronics tv = new Electronics("Samsung G5120", "Samsung", 42999, 5.0, new DateTime(2022, 1, 1), 4, 150, "G5120");
productList.AddProduct(tv);

Books mybook = new Books("Удержать небо", "Издательство АСТ", 1099, 0.6, new DateTime(2021, 1, 1), "Лю Цысинь", 448, "978-5-17-103394-7");
productList.AddProduct(mybook);

// Вывод информации о продуктах
Console.WriteLine("Информация о продуктах:");
foreach (var product in productList.FilterByPrice(50000))
{
    Console.WriteLine(product.GetInfo());
    product.Discount();
    product.Display();
    product.CalculateShippingCost();

    if (product is Fiction fiction)
    {
        fiction.CalculateReadingTime(20);
        fiction.CheckAvailability();
        fiction.RecommendSimilarBooks();
    }
    else if (product is Clothing clothing)
    {
        ((IClothes)clothing).CheckFit(56);
        clothing.ChangeColor("Белый");
    }
    else if (product is Electronics electronics)
    {
        electronics.CalculateEnergyCost(5, 365, 0.1);
        electronics.CheckCompatibility("G5120");
    }
    else if (product is Books book)
    {
        book.CalculateReadingTime(25);
        book.CheckAvailability();
    }

    Console.WriteLine();
}

productList.DisplayAll();

var affordableProducts = productList.FilterByPrice(2000);
Console.WriteLine("\nДоступные товары по цене до 2000 руб.:");
foreach (var product in affordableProducts)
{
    Console.WriteLine(product.GetInfo());
}

static void OnProductAdded(Product product)
{
    Console.WriteLine($"Добавлен новый продукт: {product.Name}");
}
// Out:
// Добавлен новый продукт: 1984
// Добавлен новый продукт: Худи
// Добавлен новый продукт: Samsung G5120
// Добавлен новый продукт: Удержать небо
// Информация о продуктах:
// Название - 1984; Производитель - Издательство АСТ; Цена - 239 руб.; Вес - 0.5 кг.; Дата выпуска - 08.06.1949; Автор - Дж. Оруэлл; Страниц - 328; ISBN - 978-5-17-103394-7; Жанр - Художественная литература
// Применена скидка на '1984' от производителя Издательство АСТ. Итоговая стоимость - 179.25 руб.
// Отображение товара 1984 от Издательство АСТ на экране.
// Стоимость доставки для 1984 - 5 руб.
//
// Время чтения книги '1984' - 16 часов.
//
// Книга '1984' доступна в наличии.
//
// Рекомендуем книги в жанре Художественная литература.
//
//
// Название - Худи; Производитель - OffWhite; Цена - 19299 руб.; Вес - 0.8 кг.; Дата выпуска - 01.01.2023; Размер - 56; Материал - Хлопок; Цвет - Черный
// Применена скидка на 'Худи' от производителя OffWhite. Итоговая стоимость - 14474.25 руб.
// ...
